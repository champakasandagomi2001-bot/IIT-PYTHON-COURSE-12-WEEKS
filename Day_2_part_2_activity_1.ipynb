# %% [markdown]
# ACTIVITY 01
#
# #Question 1: Multi-Variable Collection
# Text:
#
# Use the input() function to ask a user for their pet_name, home_town, and dream_job. Store each response in a variable that follows standard Python naming conventions

# %%
pet_name=input("enter pet name")
home_town=input("enterhome town")
dream_job=input("enter dream job")

print(type(pet_name))
print(type(home_town))
print(type(dream_job))

# %% [markdown]
# #Question 2: Integer Conversion
# Text:
#
# Ask the user for their birth_year using the input() function. Convert that input into an integer and store it in a variable named year_born.

# %%
enter_year_born=int(input("enter your birth year"))
print(type(enter_year_born))

# %% [markdown]
# #Question 3: Boolean Assignment
# Text:
#
# Create a variable named has_subscription. Assign it a boolean value (True or False) that represents whether a user is currently a member.

# %%
has_subscription=False
has_subscription=True
print(type(has_subscription))

# %% [markdown]
# Question 4: Float Conversion
# Text:
#
# Ask the user for the price of a cup of coffee (e.g., 3.50) using input(). Convert this input into a float and store it in a variable named coffee_price.

# %%
price_coffee=float(input("enter price of cup of cofee"))
print(type(price_coffe))

# %% [markdown]
# #Question 5: Mixed Type Storage
# Text:
#
# Ask the user for their item_name (string) and the quantity_available (integer) using two separate input() calls. Ensure the quantity is converted to the correct numeric type.

# %%
enter_name=input("Enter yourname")
quantity_available=int(input("quantity_available"))
print(type(enter_name))
print(type(quantity_available))
