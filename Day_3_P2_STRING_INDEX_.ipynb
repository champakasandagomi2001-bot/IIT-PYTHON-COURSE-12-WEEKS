# %%
num1=input("Enter the first number")
num2=input("Enter the second number")

sum1=num1+num2
print(sum1)
# Out:
# Enter the first number 55
# Enter the second number 66
# 5566

# %%
num1=int(input("Enter the first number"))
num2=int(input("Enter the second number"))
sum1=num1+num2
print(sum1)
# Out:
# Enter the first number 55
# Enter the second number 66
# 121

# %%
##print with space and meaningfully

first_name = "Champa"
second_name = "Sandagomi"
age = 24

print("My name is", first_name, second_name, "I am", age, "years old")
# Out:
# My name is Champa Sandagomi I am 24 years old

# %%
##formated string

print(f"My name is {first_name} {second_name},i am {age} years old")
# Out:
# My name is Champa Sandagomi,i am 24 years old

# %%
##new line charactorl

print("Hello\nWorld\nHow\nAre\nYou")
# Out:
# Hello
# World
# How
# Are
# You

# %%
ultiline_speech = """This is line one.this is line two.
and this is the
end"""

print(multiline_speech)
# Out:
# This is line one. This is line two.
# And this is the
# end.

# %%
##EG-

address = """Champaka Sandagomi
123 Main Street
Colombo
Sri Lanka"""

# %%
##key word argument

print("HELLO")
print("WORLD")
print("HELLO", end="")
print("WORLD")
# Out:
# HELLO
# WORLD
# HELLOWORLD

# %%
#indexing

name=("HELLO SRI LANkA")
print(name[0])
print(name[-4])
print(name[11])
# Out:
# H
# A
# A

# %%
#SLISING
name=("HELLO SRI LANkA")
print(name[1:14])
print(name[1:11])
# Out:
# ELLO SRI LANk
# ELLO SRI L

# %%
name=("HELLO SRI LANkA")
print(name.upper())
print(name.upper())
print(name.lower())
# Out:
# HELLO SRI LANKA
# HELLO SRI LANKA
# hello sri lanka
