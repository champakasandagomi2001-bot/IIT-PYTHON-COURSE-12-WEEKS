# %%
Y=20
print(type(Y))
# Out:
# <class 'int'>

# %%
Y=30
X=20
print(X+Y)
# Out:
# 50

# %%
Z=60
X=80
Y=45
print(Z+Y-X)
# Out:
# 25

# %%
Y="Champaka"
print(type(Y))
# Out:
# <class 'str'>

# %%
Y=10.5
X=55.96
Z=77.85
K="Champaka"
print(X+Y-Z)
# Out:
# -11.389999999999986

# %%
print(type(K))
# Out:
# <class 'str'>

# %%
Y=99.66
print(type(Y))
# Out:
# <class 'float'>

# %%
Y=562
print(type(Y))
# Out:
# <class 'int'>

# %%
CHAMPAKA_IS_24_YEARS_OLD=True
CHAMPAKA_IS_28_YEARS_OLD=False
print(CHAMPAKA_IS_24_YEARS_OLD)
print (type(CHAMPAKA_IS_28_YEARS_OLD))
# Out:
# True
# <class 'bool'>

# %%
Name="kamal"
age=25
height=5.9

print(Name)
print(age)
print(height)

print(type(Name))
print(type(age))
print(type(height))

# %% [markdown]
# #PYTHON WEEK_2 ACTIVITY_01

# %%
my_age=input("what is your age")
print=my_age
