# %%
list_01=[]
print(type(list_01))
print(list_01)
# Out:
# <class 'list'>
# []

# %%
list_01=[]
print(type(list_01))
print(list_01)
# Out:
# <class 'list'>
# []

# %%
mylist_03=[10,30,50,60,70,80]
print(mylist3)

print(type(mylist_03))
# Out:
# [10, 30, 50, 60, 70, 80]
# <class 'list'>

# %%
fruits = ["apple","banana","cherry","apple","cherry"]
print(fruits)
# Out:
# ['apple', 'banana', 'cherry', 'apple', 'cherry']

# %%
#append

numbers=[5,10,15,20,44]
numbers.append(25)
print(numbers)
# Out:
# [5, 10, 15, 20, 44, 25]

# %%
#replace with indexing
Fruits_02=["apple","Banana","Cherry"]
Fruits_02[1]="orange"
print(Fruits_02)
# Out:
# ['apple', 'orange', 'Cherry']

# %%
#replace with indexing
Fruits_02=["apple","Banana","Cherry"]
Fruits_02[0]="orange"
print(Fruits_02)
# Out:
# ['orange', 'Banana', 'Cherry']

# %%
#adding iteams to an specific position
Fruits_04=["apple","Banana","Mango"]
Fruits_04.insert(1,"cherry")
print(Fruits)
# Out:
# ['apple', 'cherry', 'Banana', 'Mango']

# %%
my_list = [10,"Champaka",22,"Ann",False]
print(my_list[0])
print(my_list[:3])
print(my_list[::-1])
print(my_list[:])
print(my_list[2:5])
print(my_list[2:])
print(my_list[2:5:2])
# Out:
# 10
# [10, 'Champaka', 22]
# [False, 'Ann', 22, 'Champaka', 10]
# [10, 'Champaka', 22, 'Ann', False]
# [22, 'Ann', False]
# [22, 'Ann', False]
# [22, False]

# %%
my_list = [10,"Champaka",22,"Ann",False]
print(my_list[::-3])
# Out:
# [False, 'Champaka']

# %%
my_list_05 = [10, 20, 30, 10, 40, 30, 80, 30, 50]

print(len(my_list_05))
print(my_list_05.index(30))
print(my_list_05.count(40))
# Out:
# 9
# 2
# 1
