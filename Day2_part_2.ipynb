# %%
my_age=input("enter your age")
print=my_age

# %%
my_name=("Enter my age")
print=my_name

# %%
number1=("enter the first numbre")
number2=("enter the second number")
print(number1)
print(number2)
