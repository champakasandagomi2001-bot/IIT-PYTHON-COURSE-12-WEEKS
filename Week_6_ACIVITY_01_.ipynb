# %%
my_list=[5,10,15,20]
print(my_list[1])
print(my_list[-1])
# Out:
# 10
# 20

# %%
Given_nums=[2,4,6,8,10]
print(Given_nums[1:4])
# Out:
# [4, 6, 8]

# %%
pets=["dog","fish","bird"]
pets[0]="cat"
print(pets)
# Out:
# ['cat', 'fish', 'bird']

# %%
fruits=["orange","mango","banana"]
fruits.append("orange")
print(fruits)

fruits.insert(2,"papaya")
print(fruits)
# Out:
# ['orange', 'mango', 'banana', 'orange']
# ['orange', 'mango', 'papaya', 'banana', 'orange']

# %%
vehicles=["bus","car","van"]
vehicles.pop(1)
print(vehicles)
# Out:
# ['bus', 'van']
