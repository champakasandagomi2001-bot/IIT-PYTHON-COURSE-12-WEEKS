# %%
while True:
  user_input=input(f"Welcome to the chatbot service of ABC Bank? type 'Exit'to exit from the chat bot service")
  user_input=user_input.lower()
  print(user_input)

if user_input=="Exit":
  print("Good bye")
  break

elif user_input in ["Hi","Hello","Hay"]:
  print("Hello im your bank chat bot, how can i help you")

elif"name"in user_input:
  print("my name is bank chat bot, i am here to guid you with digitel banking")
elif"bank balance"in user_input:
  print("Hello, can you share your account number with me?")
elif"contact information"in user_input:
  print("you can contact us via +942211236, abcbank@bank.lk")
# Out:
# exit
# name
# bank balance
# contact information
# name
