# %%
age=int(input("Enter the age"))

if age>18:
    print("adult")
else:
    print("minor")
# Out:
# Enter the age 3
# minor

# %%
marks=int(input("Enter the marks"))

if marks>=75:
    print("Geade A")
elif marks>=65:
    print("Grade B")
elif marks>=55:
    print("Grade C")
else:
    print("Fail")
# Out:
# Enter the marks 55
# Grade C

# %%
number=int(input("Enter the number"))

if number>0:
    print("positive")
elif number<0:
    print("negative")
else:
    print("zero")
# Out:
# Enter the number -44
# negative

# %%
name=input("Enter the name")
marks=int(input("Enter the marks"))

if marks>85:
    print("Grade A")
elif marks>75:
    print("Grade B")
elif marks>60:
    print("Grade C")
elif marks>=50:
    print("Grade D")
else:
    print("Fail")
# Out:
# Enter the name champaka
# Enter the marks 88
# Grade A

# %%
x=3
y=7
if x>y:
    print("x is grater")
elif x==y:
    print("x and y are equal")
else:
    print("y is grator")
# Out:
# y is grator

# %%
marks=int(input("Enter the marks (0-100)"))

if marks>=90 and marks<=100:
    print("A")
elif marks>=80:
    print("B")
elif marks>=70:
    print("C")
elif marks>=60:
    print("D")
elif marks>=0:
    print("Fail")
else:
    print("Invalid score enterd")
# Out:
# Enter the marks (0-100) 222
# B

# %%
x = int(input("Enter x: "))

if (x > 100):
    k = x * 2

    if (x >= 200):
        k = k * 3

    elif (k < 300):
        k = k * 4

    else:
        k = k * 5

else:
    k = x * 3

print(k)
# Out:
# Enter x:  111
# 888

# %%
m = int(input("Enter an integer: "))

if (m < 1000):
    p = 2000 / m
else:
    p = m / 1000
# Out:
# Enter an integer:  100
