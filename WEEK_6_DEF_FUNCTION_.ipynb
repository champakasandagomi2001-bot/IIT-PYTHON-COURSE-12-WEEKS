# %%
def greet():
  print("Hello world")

# %%
greet()
# Out:
# Hello world

# %%
def greet(name):
  print(f"Hello,{name}!")
greet("senaka")
# Out:
# Hello,senaka!

# %%
def add_numbers(a,b):
  return a+b

# %%
def square (umber):
  return umber*umber
