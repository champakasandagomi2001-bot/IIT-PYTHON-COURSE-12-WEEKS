# %% [markdown]
# ### PYTHON PROGRAMMING

# %% [markdown]
# ## DAY 1

# %%
print("Hellow, World!")
# Out:
# Hellow, World!

# %% [markdown]
# # i develop this 2026 hoping to learn python and become a pro of it (Allso you can yse 3 # and press enter)

# %%
print("Hellow, World!")
print("Hi Srilanka")
print('Hellow People')
# Out:
# Hellow, World!
# Hi Srilanka
# Hellow People

# %% [markdown]
# # LEVEL 1
# ## LEVEL 2
# ### LEVEL 3

# %% [markdown]
# ## DAY 1

# %%
print("My name is champaka Sandagomi")
print("i'm a udergraduate studient in a univercity")
print("im earning python")
print("im currenty earning cyber sicurity")
# Out:
# My name is champaka Sandagomi
# i'm a udergraduate studient in a univercity
# im earning python
# im currenty earning cyber sicurity
