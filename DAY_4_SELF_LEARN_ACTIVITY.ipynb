# %%
##Write a Python program to print the multiplication table of 5.

for i in range(1, 11):
    print(f"5 x {i} = {5 * i}")
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %%
##My name is Alex and I am 17 years old.

name="Champaka"
age=24

print(f"my name is {name} and i am {age} years old")
# Out:
# my name is Champaka and i am 24 years old

# %%
##Write a program that stores two numbers and prints their sum.

num1=int(input("enter first number"))
num2=int(input("enter first number"))

print(f"{num1}+{num2}={num1+num2}")
# Out:
# enter first number 22
# enter first number 22
# 22+22=44

# %%
##Write a program that stores a number and prints its square.

number=int(input("enter the number"))

print(f"the square of {number} is{number*number} ")
# Out:
# enter the number 6
# the square of 6 is36

# %%
##Write a program to print the numbers 1 to 5 and their squares.

for i in range (1,6):
    print(f" {i} squared = {i*i} ")
# Out:
#  1 squared = 1
#  2 squared = 4
#  3 squared = 9
#  4 squared = 16
#  5 squared = 25

# %%
##Write a program to print the numbers 2 to 10 and their squares.

for i in range (2,10,2):
    print(f"{i} in squared {i*i}")
# Out:
# 2 in squared 4
# 4 in squared 16
# 6 in squared 36
# 8 in squared 64

# %%
##Write a program to print the multiplication table of 5 from 1 to 10.

for i in range (1,10):
    print(f"5x{i}={i*5}")
# Out:
# 5x1=5
# 5x2=10
# 5x3=15
# 5x4=20
# 5x5=25
# 5x6=30
# 5x7=35
# 5x8=40
# 5x9=45

# %%
##Write a program to print the multiplication table of 7 from 2.

for i in range (2,20,2):
    print(f"2x{i}={2*i}")
# Out:
# 2x2=4
# 2x4=8
# 2x6=12
# 2x8=16
# 2x10=20
# 2x12=24
# 2x14=28
# 2x16=32
# 2x18=36
