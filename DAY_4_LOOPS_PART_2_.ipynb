# %%
for spellings in "CHAMPAKA":
    print(spellings,end="   ")
# Out:
# C   H   A   M   P   A   K   A

# %%
correct_password = "abc@123"
password = input("enter password")
while password != correct_password:
    print("incorrect password try again")
    password = input("enter password")
print("Access granted")
# Out:
# enter password 123666
# incorrect password try again
# enter password 196803302002
# incorrect password try again
# enter password abc@123
# Access granted

# %%
while True:
    command = input("type 'exit' to quit:")
    if command == "exit":
     break
# Out:
# type 'exit' to quit: open
# type 'exit' to quit: unlock
# type 'exit' to quit: wxit
# type 'exit' to quit: exit

# %%
import time
battery = 10
while battery>0:
    print("battery level:",battery)
    battery -=1
    time.sleep(1)
print("battery empty!")
# Out:
# battery level: 10
# battery level: 9
# battery level: 8
# battery level: 7
# battery level: 6
# battery level: 5
# battery level: 4
# battery level: 3
# battery level: 2
# battery level: 1
# battery empty!

# %%
age=-1
while age<=0:
    age=int(input("Enter the valid age"))
print("Thank you")
# Out:
# Enter the valid age -77
# Enter the valid age -44
# Enter the valid age 88
# Thank you

# %%
choice=""
while choice!="3":
    print("1.add\n2. view\n3.exit")
    choice=input("choose an option")
print("Goodbye")
# Out:
# 1.add
# 2. view
# 3.exit
# choose an option 2
# 1.add
# 2. view
# 3.exit
# choose an option 1
# 1.add
# 2. view
# 3.exit
# choose an option 3
# Goodbye

# %%
##Example 3 (using for loop)

for i in range(1,6):
    print("@"*i)
# Out:
# @
# @@
# @@@
# @@@@
# @@@@@

# %%
##Example 3 (using for while)


i=1
while i<=5:
    print("@"*i)
    i+=1
# Out:
# @
# @@
# @@@
# @@@@
# @@@@@

# %%
for i in range(2):
    for j in range(3):
        print(i, j)
# Out:
# 0 0
# 0 1
# 0 2
# 1 0
# 1 1
# 1 2

# %%
for i in range(1,4):
    for j in range(i):
        print("*",end="")
    print()
# Out:
# *
# **
# ***

# %%
for i in range(1, 11):
    print(f"5 x {i} = {5 * i}")
# Out:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50
